# %% [markdown]
# #### Loading the data using python pandas library.

# %%
import pandas as pd
df=pd.read_csv("Indian_Kids_Screen_Time.csv")

# %% [markdown]
# #### Displaying first five records of our data to see the data format

# %%
df.head(10)
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
# 5   14  Female                      4.88     Smartphone
# 6   17    Male                      2.97             TV
# 7   10    Male                      2.74             TV
# 8   14    Male                      4.61         Laptop
# 9   18    Male                      3.24         Tablet
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# ...

# %% [markdown]
# #### tail() defaultly shows last 5 records

# %%
df.tail(5)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9707   17    Male                      3.26     Smartphone
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# ...

# %% [markdown]
# #### describe() function gives the statistical measures of the data. By this we can see the count(total number of rows),mean, std, etc. values which gives us some insights about our data

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %% [markdown]
# #### this function gives the shape of the data i.e (number of rows,number of columns)

# %%
df.shape
# Out:
# (9712, 8)

# %% [markdown]
# #### this function gives info() about our data i.e datatypes of each columns, total non-null values in each columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %% [markdown]
# #### this function sum the null values of each columns seperately and show it to us. From this we can see that only health_impacts columns has null values.So we can replace those missing values if we want

# %%
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %% [markdown]
# #### this function shows if any duplicate rows are there in our data. If any we can remove that column so that memory usage reduces and data redundancy removes

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9707    False
# 9708    False
# 9709    False
# 9710    False
# 9711    False
# Length: 9712, dtype: bool

# %% [markdown]
# #### this retrives our desired rows from our desired columns

# %%
df1=df[["Avg_Daily_Screen_Time_hr","Primary_Device"]][0:10:1]
df1
# Out:
#    Avg_Daily_Screen_Time_hr Primary_Device
# 0                      3.99     Smartphone
# 1                      4.61         Laptop
# 2                      3.73             TV
# 3                      1.21         Laptop
# 4                      5.89     Smartphone
# 5                      4.88     Smartphone
# 6                      2.97             TV
# 7                      2.74             TV
# 8                      4.61         Laptop
# 9                      3.24         Tablet

# %% [markdown]
# ### Univariate Analysis

# %%
#histogram
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
sns.histplot(data=df,x='Avg_Daily_Screen_Time_hr',kde=True,bins=30)
plt.title('Distribution of Values')
plt.xlabel('Avg_Daily_Screen_Time_hr')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Histogram
# #### This histogram shows the distribution of screentime among the values. By this we can see mostly childrens see the scree between 4 to 6 hrs. So we can easily conlcude it using this rather than seeing entire data manually

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Age')
plt.show()

# %% [markdown]
# #### This plot shows the distribution of age in the data. From this we can see in our data we have data of children from age 8 to 18 and almost same frequency for each age.

# %%
#count plot=>shows how many members uses devices based on gender
plt.figure(figsize=(8,7))
sns.countplot(data=df,x='Gender',hue='Primary_Device',palette='pastel')
plt.title("Count of Participants by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Countplot
# #### this visualization shows us for each gender how many members use each type of device. By this we can say either male or female most of use smartphone

# %%
#shows how many members uses each type of device
plt.figure(figsize=(8,7))
sns.countplot(data=df,x='Primary_Device',hue='Primary_Device',palette='colorblind')
plt.title("Count of Participants by type of Device")
plt.xlabel("Type of Device")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### this count plot show the total count of users for each device seperately. This also give same insight as before that most of using smartphone

# %%
plt.figure(figsize=(8,7))
sns.countplot(data=df,x='Urban_or_Rural',hue='Urban_or_Rural',palette='dark')
plt.title("Count of Participants by type of Location")
plt.xlabel("Location")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### this countplot shows the count of users based on location type i.e urban or rural. Here most of users are from urban areas

# %%
data=df["Avg_Daily_Screen_Time_hr"]
sns.kdeplot(data=data,fill=True)
plt.title("Avg_Daily_Screen_Time_hr KDE plot")
plt.show()

# %% [markdown]
# ### this is the kdeplot similar to histogram but here we can see the distribution clearly then histogram

# %%
data=df["Age"]
sns.kdeplot(data=data,fill=True)
plt.title("Age KDE plot")
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
#violin plot=>shows usage of screentime by gender
plt.figure(figsize=(8,5))
sns.violinplot(x='Gender',y='Avg_Daily_Screen_Time_hr',hue='Primary_Device',data=df)
plt.title("Screen_time by Gender")
plt.xlabel("Gender")
plt.ylabel("Screen_time")
plt.show()

# %% [markdown]
# #### this violin plots gives more information and we can easily understand it. As you see the shape at which it is enlarged shows the most used screentime. It is between 4 to 6hrs same as seen in histogram.

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x='Age',y='Avg_Daily_Screen_Time_hr',hue='Age',data=df,palette='dark')
plt.title("Screen_time by Age")
plt.xlabel("Age")
plt.ylabel("Screen_time")
plt.show()

# %% [markdown]
# #### this shows the screentime distributed by age. We add colors to make it more effective and to differentiate

# %%
#Boxplot
plt.figure(figsize=(10,5))
sns.boxplot(x="Gender",y="Avg_Daily_Screen_Time_hr",hue="Gender",legend=False,data=df,palette="viridis")
plt.title("Box plot of Average ScreenTime by Gender")
plt.show()

# %% [markdown]
# ### Boxplot=>shows the screen time by gender
# #### Boxplots gives here that either male or female most of them use screen between 4 to 6hrs

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="Age",y="Avg_Daily_Screen_Time_hr",data=df,hue="Age",palette="viridis",legend=False)
plt.title("Box plot of Average ScreenTime by Age")
plt.show()

# %% [markdown]
# #### this gives the screentime distribution by age using boxplot. Here also we can see most of them using the screen between 4 to 6 hrs

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df,x='Age',y='Avg_Daily_Screen_Time_hr',size='Age',hue='Gender',palette='colorblind')
plt.title("Scatter plot Age vs Screentime")
plt.show()

# %% [markdown]
# #### this is the visualtization of scatterplot which shows the screentime distribution for each age.Here we set the legend as gender so we can see the male and female differentiation here easily. From this we can draw some insights using this

# %% [markdown]
# ### Grouped barplots
# #### Grouped barplots helps us to visualize more efficiently by setting legend columns. Is is used for comparison. Here we plot it for distribution of screentime for different devices by gender and another one is for different age by gender

# %%
sns.barplot(data=df,x='Primary_Device',y='Avg_Daily_Screen_Time_hr',hue='Gender',palette='dark')
plt.title("Group barplot for different devices by Gender")
plt.show()

# %%
sns.barplot(data=df,x='Age',y='Avg_Daily_Screen_Time_hr',hue='Gender',palette='deep')
plt.title("Group barplot for different ages by Gender")
plt.show()

# %% [markdown]
# ### Facet Grid
# #### We plot different plots i.e scatter, histogram, kde, etc. It gives different plots for our selected columns. Here we plot scatter plot for screentime for each device. It gives the scatter plot for each gender seperately. So that we can easily visualize and understand the data using this.

# %%
g=sns.FacetGrid(df,col='Primary_Device',hue="Age")
g.map(plt.scatter,'Gender','Avg_Daily_Screen_Time_hr')
plt.show()

# %%
g = sns.FacetGrid(df, col='Gender', row='Primary_Device', margin_titles=True, despine=False)
g.map(plt.hist, 'Avg_Daily_Screen_Time_hr', bins=20, color='skyblue', edgecolor='black')
g.fig.suptitle("Distribution of Average Daily Screen Time by Gender and Primary Device")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Above plots gives the distribution of screen time for each device by each gender seperately. By this we can draw the insights which device mostly used, screentime by each device and each gender screentime usage by each device. We see all of these using this single plot. Thats why facet grid is most useful as coming to plotting

# %% [markdown]
# ### Pairplots
# #### Pairplots describe the relationships between numerical columns in our data using kde and scatter plots.

# %%
sns.pairplot(df,hue='Age')
plt.suptitle("Pairplot:Relationship between numerical variables")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df,hue='Exceeded_Recommended_Limit')
plt.suptitle("Pairplot:Relationship between numerical variables")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.suptitle("Pairplot:Relationship between numerical variables")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Heatmap
# #### Heatmap defines the correlation between numerical columns in our data. It shows how much two columns are correlated i.e dependent on each other. The side color bar represents the color of lessly correlated to mostly correlated. The range varies from -1 to 1. 1 means positively correlated i.e one increases then another increases and -1 means negatively correlated viceversa to 1. 0 means not correlated.

# %%
plt.figure(figsize=(10,6))
numeric_columns=df.select_dtypes(include=['int64','float64'])
correlation_matrix=numeric_columns.corr()
sns.heatmap(correlation_matrix,cmap='coolwarm',annot=True)
plt.title("Heatmap:Correlation between numeric columns")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distibution plots
# #### Distibutions plots with hue defaultly gives histogram by applying hue as legend. Here we see the screentime distribution by gender.

# %%
sns.displot(data=df,x="Avg_Daily_Screen_Time_hr",hue="Gender",kind='hist')
plt.title("Distribution plot with hue(Screentime by Gender)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
pivot_df=df.pivot_table(index='Primary_Device',columns='Urban_or_Rural',values='Avg_Daily_Screen_Time_hr',aggfunc='sum',fill_value=0)
sns.barplot(x=pivot_df.index,y=pivot_df['Urban'],color='red',label='Urban')
sns.barplot(x=pivot_df.index,y=pivot_df['Rural'],bottom=pivot_df['Urban'],color='blue',label='Rural')
plt.xlabel("Primary_Device")
plt.ylabel("Count")
plt.title("Stacked barplot (Device usage by location)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Stripplot
# #### Stripplot is a type of categorical scatter plot that displays individual data points along a single axis. This stripplot shows the spread of average screen time by different devices.

# %%
sns.stripplot(x='Primary_Device',y='Avg_Daily_Screen_Time_hr',hue='Gender',data=df,jitter=True)
plt.show()

# %%
sns.stripplot(x='Gender',y='Avg_Daily_Screen_Time_hr',hue='Primary_Device',data=df,jitter=True)
plt.show()

# %% [markdown]
# #### Combination of multiple plots into subplots helps us to visualize the data in different aspects at a time

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(8,6))
sns.histplot(data=df,x='Avg_Daily_Screen_Time_hr',kde=True,bins=30,ax=axes[0,0])
axes[0,0].set_title('Distribution of Avg_Daily_Screen_Time_hr')
data=df["Avg_Daily_Screen_Time_hr"]
sns.kdeplot(data=data,fill=True,ax=axes[0,1])
axes[0,1].set_title("Avg_Daily_Screen_Time_hr KDE plot")
sns.violinplot(x='Gender',y='Avg_Daily_Screen_Time_hr',hue='Primary_Device',data=df,ax=axes[1,0])
axes[1,0].set_title("Screen_time by Gender")
sns.boxplot(x="Gender",y="Avg_Daily_Screen_Time_hr",hue="Gender",legend=False,data=df,palette="viridis",ax=axes[1,1])
axes[1,1].set_title("Box plot of Average ScreenTime by Gender")
plt.tight_layout()
plt.show()
