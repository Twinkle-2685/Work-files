# %%
import requests as rs
r=rs.get("https://www.geeksforgeeks.org/python-web-scraping-tutorial/")
print(r)
print(r.content)
# Out:
# <Response [200]>
# ...

# %%
from bs4 import BeautifulSoup as bs
r=rs.get("https://www.geeksforgeeks.org/python-web-scraping-tutorial/")
soup=bs(r.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US" prefix="og: http://ogp.me/ns#">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US" prefix="og: http://ogp.me/ns#">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Data Structures, Algorithms, Python, Java, C, C++, JavaScript, Android Development, SQL, Data Science, Machine Learning, PHP, Web Development, System Design, Tutorial, Technical Blogs, Interview Experience, Interview Preparation, Programming, Competitive Programming, Jobs, Coding Contests, GATE CSE, HTML, CSS, React, NodeJS, Placement, Aptitude, Quiz, Computer Science, Programming Examples, GeeksforGeeks Courses, Puzzles, SSC, Banking, UPSC, Commerce, Finance, CBSE, School, k12, General Knowledge, News, Mathematics, Exams" name="keywords"/>
# ...

# %%
soup=bs(r.text,"html.parser")
print(soup.a)
# Out:
# <a class="gfg-stc" href="#main" style="top:0">Skip to content</a>

# %%
soup=bs(r.text,"html.parser")
print(soup.div.prettify())
# Out:
# <div class="header-main__wrapper">
#  <a class="gfg-stc" href="#main" style="top:0">
#   Skip to content
#  </a>
#  <a aria-label="Logo" class="header-main__logo" href="https://www.geeksforgeeks.org/">
#   <div class="_logo">
#    <!-- Original Logo -->
#    <img alt="geeksforgeeks" class="gfg_logo_img" src="https://media.geeksforgeeks.org/gfg-gg-logo.svg" style="height: 30px; width: 80px; max-width: fit-content;"/>
#   </div>
#  </a>
#  <div class="header-main__container">
#   <span class="hamburger-menu">
#    <span class="gfg-burger-1">
#    </span>
#    <span class="gfg-burger-2">
#    </span>
#    <span class="gfg-burger-3">
#    </span>
#   </span>
#   <ul class="header-main__list">
#    <li aria-expanded="true" class="header-main__list-item" data-expandable="true" data-parent="false">
#     <span>
#      Courses
#     </span>
#     <i class="gfg-icon gfg-icon_arrow-down gfg-icon_header">
#     </i>
#     <ul class="mega-dropdown">
# ...

# %%
soup=bs(r.text,"html.parser")
print(soup.div.li.prettify())
# Out:
# <li aria-expanded="true" class="header-main__list-item" data-expandable="true" data-parent="false">
#  <span>
#   Courses
#  </span>
#  <i class="gfg-icon gfg-icon_arrow-down gfg-icon_header">
#  </i>
#  <ul class="mega-dropdown">
#   <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#    <a href="https://www.geeksforgeeks.org/courses/dsa-to-development-coding-guide?utm_source=geeksforgeeks&amp;utm_medium=main_header&amp;utm_campaign=courses" target="_self">
#     DSA to Development
#    </a>
#   </li>
#   <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="false">
#    <span>
#     For Working Professionals
#    </span>
#    <i class="gfg-icon gfg-icon_arrow-right">
#    </i>
#    <ul class="mega-dropdown">
#     <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
# ...

# %%
soup=bs(r.text,"html.parser")
print(soup.div.span.prettify())
# Out:
# <span class="hamburger-menu">
#  <span class="gfg-burger-1">
#  </span>
#  <span class="gfg-burger-2">
#  </span>
#  <span class="gfg-burger-3">
#  </span>
# </span>

# %%
soup=bs(r.text,"html.parser")
print(soup.div.li.attrs)
# Out:
# {'class': ['header-main__list-item'], 'data-parent': 'false', 'aria-expanded': 'true', 'data-expandable': 'true'}

# %%
soup=bs(r.text,"html.parser")
print(soup.div.span.attrs)
# Out:
# {'class': ['hamburger-menu']}

# %%
soup=bs(r.text,"html.parser")
at=soup.div.li.attrs
print(at["class"])
# Out:
# ['header-main__list-item']

# %%
soup=bs(r.text,"html.parser")
print(soup.div.li.span.string)
# Out:
# Courses

# %%
soup=bs(r.text,"html.parser")
print(soup.head)
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="Data Structures, Algorithms, Python, Java, C, C++, JavaScript, Android Development, SQL, Data Science, Machine Learning, PHP, Web Development, System Design, Tutorial, Technical Blogs, Interview Experience, Interview Preparation, Programming, Competitive Programming, Jobs, Coding Contests, GATE CSE, HTML, CSS, React, NodeJS, Placement, Aptitude, Quiz, Computer Science, Programming Examples, GeeksforGeeks Courses, Puzzles, SSC, Banking, UPSC, Commerce, Finance, CBSE, School, k12, General Knowledge, News, Mathematics, Exams" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0" name="viewport"/>
# <link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# ...

# %%
soup=bs(r.text,"html.parser")
sp=soup.find("p")
print(sp.string)
# Out:
# Web scraping, the process of extracting data from websites, has emerged as a powerful technique to gather information from the vast expanse of the internet. In this tutorial, we’ll explore various Python libraries and modules commonly used for web scraping and delve into why Python 3 is the preferred choice for this task.

# %%
soup=bs(r.text,"html.parser")
print(soup.find("div"))
# Out:
# <div class="header-main__wrapper">
# <a class="gfg-stc" href="#main" style="top:0">Skip to content</a>
# <a aria-label="Logo" class="header-main__logo" href="https://www.geeksforgeeks.org/">
# <div class="_logo">
# <!-- Original Logo -->
# <img alt="geeksforgeeks" class="gfg_logo_img" src="https://media.geeksforgeeks.org/gfg-gg-logo.svg" style="height: 30px; width: 80px; max-width: fit-content;"/>
# </div>
# </a>
# <div class="header-main__container">
# <span class="hamburger-menu">
# <span class="gfg-burger-1"></span>
# <span class="gfg-burger-2"></span>
# <span class="gfg-burger-3"></span>
# </span>
# ...

# %%
soup=bs(r.text,"html.parser")
print(soup.find("li").prettify())
# Out:
# <li aria-expanded="true" class="header-main__list-item" data-expandable="true" data-parent="false">
#  <span>
#   Courses
#  </span>
#  <i class="gfg-icon gfg-icon_arrow-down gfg-icon_header">
#  </i>
#  <ul class="mega-dropdown">
#   <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
#    <a href="https://www.geeksforgeeks.org/courses/dsa-to-development-coding-guide?utm_source=geeksforgeeks&amp;utm_medium=main_header&amp;utm_campaign=courses" target="_self">
#     DSA to Development
#    </a>
#   </li>
#   <li aria-expanded="true" class="mega-dropdown__list-item" data-expandable="true" data-parent="false">
#    <span>
#     For Working Professionals
#    </span>
#    <i class="gfg-icon gfg-icon_arrow-right">
#    </i>
#    <ul class="mega-dropdown">
#     <li aria-expanded="false" class="mega-dropdown__list-item" data-child="true" data-expandable="false">
# ...

# %%
soup=bs(r.text,"html.parser")
print(soup.find_all("p"))
# Out:
# [<p dir="ltr"><span>Web scraping, the process of extracting data from websites, has emerged as a powerful technique to gather information from the vast expanse of the internet. In this tutorial, we’ll explore various Python libraries and modules commonly used for web scraping and delve into why Python 3 is the preferred choice for this task.</span></p>, <p dir="ltr"><span>The latest version of </span><a href="https://www.geeksforgeeks.org/python-programming-language/" rel="noopener" target="_blank"><span>Python</span></a><span>, offers a rich set of tools and libraries specifically designed for web scraping, making it easier than ever to retrieve data from the web efficiently and effectively.</span></p>, <p style="margin:4px; font-size:20px; font-weight:bold;">Table of Content</p>, <p dir="ltr"><span>The requests library is used for making HTTP requests to a specific URL and returns the response. Python requests provide inbuilt functionalities for managing both the request and respon
# ...

# %%
soup=bs(r.text,"html.parser")
print(soup.p.attrs)
# Out:
# {'dir': 'ltr'}

# %%
soup=bs(r.text,"html.parser")
pr=soup.find_all("p",dir="ltr")
print(len(pr))
# Out:
# 39

# %% [markdown]
# soup=bs(r.text,"html.parser")
# pr=soup.find_all("p",dir="ltr")
# for i in pr:
#     print(i.text)

# %%
urls=[]
for link in soup.find_all("a"):
    print(link.get('href'))
# Out:
# #main
# https://www.geeksforgeeks.org/
# https://www.geeksforgeeks.org/courses/dsa-to-development-coding-guide?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/geeks-classes-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/system-design-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/Java-backend-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/devops-live?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/Data-Structures-With-Python?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# https://www.geeksforgeeks.org/courses/complete-interview-preparation?utm_source=geeksforgeeks&utm_medium=main_header&utm_campaign=courses
# ...

# %%
urls=[]
for link in soup.find_all('img'):
    print(link.get('src'))
# Out:
# https://media.geeksforgeeks.org/gfg-gg-logo.svg
# https://media.geeksforgeeks.org/auth-dashboard-uploads/Group-23726.png
# https://media.geeksforgeeks.org/wp-content/uploads/20211023185655/PythonrequestsmakingGETrequest.png
# https://media.geeksforgeeks.org/wp-content/uploads/20211023191537/PythonBeautifulSoupParsingHTML.png
# https://media.geeksforgeeks.org/wp-content/uploads/20210323145458/findallbs4pythontutorial.jpg
# https://media.geeksforgeeks.org/wp-content/uploads/20210323152640/findallbs4.png
# https://media.geeksforgeeks.org/wp-content/uploads/20240308160217/for-firefox.png
# https://media.geeksforgeeks.org/wp-content/uploads/20210226111840/scrapemultiplepagespythonselenium.png
# https://media.geeksforgeeks.org/wp-content/uploads/20240308160419/uutt.png
# https://media.geeksforgeeks.org/wp-content/uploads/20210320104649/Mouseclick.gif
# https://media.geeksforgeeks.org/wp-content/uploads/20210629200554/Screenshot20210629at80230PM.png
# ...

# %%
urls=[]
for link in soup.find_all('meta'):
    print(link.get('content'))
# Out:
# None
# Data Structures, Algorithms, Python, Java, C, C++, JavaScript, Android Development, SQL, Data Science, Machine Learning, PHP, Web Development, System Design, Tutorial, Technical Blogs, Interview Experience, Interview Preparation, Programming, Competitive Programming, Jobs, Coding Contests, GATE CSE, HTML, CSS, React, NodeJS, Placement, Aptitude, Quiz, Computer Science, Programming Examples, GeeksforGeeks Courses, Puzzles, SSC, Banking, UPSC, Commerce, Finance, CBSE, School, k12, General Knowledge, News, Mathematics, Exams
# width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0
# #308D46
# index, follow, max-image-preview:large, max-snippet:-1
# https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png
# image/png
# 200
# 200
# xo7t4ve2wn3ywfkjdvwbrk01pvdond
# ...

# %%
urls=[]
for link in soup.find_all('script'):
    print(link.get('src'))
# Out:
# https://apis.google.com/js/platform.js
# //cdnjs.cloudflare.com/ajax/libs/require.js/2.1.14/require.min.js
# https://securepubads.g.doubleclick.net/tag/js/gpt.js
# https://cdnads.geeksforgeeks.org/prebid.js?ver=0.1
# https://cdnads.geeksforgeeks.org/gfg_ads.min.js?ver=0.1
# None
# None
# None
# None
# None
# None
# https://code.jquery.com/jquery-3.6.3.min.js?ver=3.6.3
# https://code.jquery.com/jquery-migrate-3.0.0.min.js?ver=3.0.0
# None
# https://www.geeksforgeeks.org/wp-content/themes/iconic-one/js/gfg.min.js?ver=12.59
# None
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.geeksforgeeks.org/wp-includes/js/wp-embed.min.js?ver=4.9.8
# None
# None
# None
# None
# None
# None
# https://www.googletagmanager.com/gtag/js?id=G-DWCCJLKX3X
# None
# None

# %%
import re
data=soup.find_all(string=re.compile("Web scraping"))
print(data)
print(len(data))
# Out:
# ['\r\n    {\r\n        "@context": "https://schema.org",\r\n        "@type": "Article",\r\n        "mainEntityOfPage": {\r\n          "@type": "WebPage",\r\n          "id": "https://www.geeksforgeeks.org/python-web-scraping-tutorial/"\r\n        },\r\n        "headline": "Python Web Scraping Tutorial",\r\n        "datePublished": "2021-12-03 05:40:56",\r\n        "dateModified": "2024-03-11 11:05:24",\r\n        "image": "https://media.geeksforgeeks.org/wp-content/uploads/20211023185655/PythonrequestsmakingGETrequest.png",\r\n        "author": {\r\n            "@type": "Person",\r\n            "name": "GfG"\r\n        },\r\n        "publisher": {\r\n        "@type": "Organization",\r\n        "name": "GeeksforGeeks",\r\n        "logo": {\r\n            "@type": "ImageObject",\r\n            "url": "https://media.geeksforgeeks.org/wp-content/cdn-uploads/logo-new-2.svg",\r\n            "width": "301",\r\n            "height": "40"\r\n        }\r\n        },\r\n        "description": "W
# ...

# %%
import requests
import pandas as ps
from bs4 import BeautifulSoup
r=requests.get("https://ticker.finology.in/")
soup=BeautifulSoup(r.text,"html.parser")
table=soup.find("table",class_="table table-sm table-hover screenertable")
headers=table.find_all("th")
titles=[]
for i in headers:
    title=i.text
    titles.append(title)
df=ps.DataFrame(columns=titles)
rows=table.find_all("tr")
for i in rows[1:]:
    data=i.find_all("td")
    row=[tr.text for tr in data]
    l=len(df)
    df.loc[l]=row
df['Company'] = df['Company'].apply(lambda x: x.strip())
df.to_csv("data.csv")
